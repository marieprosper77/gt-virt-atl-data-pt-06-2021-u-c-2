# %%
import pandas as pd

# %%
# The path to our CSV file
csv_path = "Resources/KickstarterData.csv"

# Read our Kickstarter data into pandas
kickstart_df = pd.read_csv(csv_path)
kickstart_df.head()
# Out:
#            id                                              photo  \
# 0  1645666704  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 1   874638240  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 2   247074984  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 3  1941196813  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 4   421961595  {"small":"https://ksr-ugc.imgix.net/assets/012...
#
#                                                 name  \
# 0  The Class Act Players Theatre Company Presents...
# 1  MR INCREDIBLE by Camilla Whitehill - VAULT Fes...
# 2                                                RUN
# 3  9th International Meeting of Youth Theatre sap...
# 4                        Get Conti to the Ed Fringe!
#
#                                                blurb    goal  pledged  \
# 0  The Class Act Players put on another one of th...  1500.0   2925.0
# 1  A brand new play about love and entitlement, b...  2500.0   2936.0
# ...

# %%
# Get a list of all of our columns for easy reference

kickstart_df.head()
# Out:
#            id                                              photo  \
# 0  1645666704  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 1   874638240  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 2   247074984  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 3  1941196813  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 4   421961595  {"small":"https://ksr-ugc.imgix.net/assets/012...
#
#                                                 name  \
# 0  The Class Act Players Theatre Company Presents...
# 1  MR INCREDIBLE by Camilla Whitehill - VAULT Fes...
# 2                                                RUN
# 3  9th International Meeting of Youth Theatre sap...
# 4                        Get Conti to the Ed Fringe!
#
#                                                blurb    goal  pledged  \
# 0  The Class Act Players put on another one of th...  1500.0   2925.0
# 1  A brand new play about love and entitlement, b...  2500.0   2936.0
# ...

# %%
# Extract "name", "goal", "pledged", "state", "country", "staff_pick",
# "backers_count", and "spotlight"
kickstart_df["name"] = kickstart_df["name"].map
kickstart_df["goal"] = kickstart_df["goal"].map
#kickstart_df["pledged"] = kickstart_df["pledged"].map("${:.2f}".format)
#kickstart_df["state"] = kickstart_df["state"].map("{:,}".format)
#kickstart_df["country"] = kickstart_df["country"].map("{:,}".format)

#kickstart_df["staff_pick"] = kickstart_df["staff_pick"].map("{:,}".format)
#kickstart_df["backers_count"] = kickstart_df["backers_count"].map("{:,}".format)
#kickstart_df["spotlight"] = kickstart_df["spotlight"].map("{:.2f}".format)
kickstart_df.head()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
# ...

# %%
# Remove projects that made no money at all
kickstart_df.dtypes
# Out:
# id                          int64
# photo                      object
# name                       object
# blurb                      object
# goal                       object
# pledged                    object
# state                      object
# slug                       object
# disable_communication        bool
# country                    object
# currency                   object
# currency_symbol            object
# currency_trailing_code       bool
# deadline                    int64
# state_changed_at            int64
# created_at                  int64
# launched_at                 int64
# staff_pick                 object
# is_starrable                 bool
# backers_count              object
# static_usd_rate           float64
# usd_pledged               float64
# creator                    object
# location                   object
# category                   object
# profile                    object
# spotlight                  object
# ...

# %%
# Collect only those projects that were hosted in the US
# Create a list of the columns
# Create a new df for "US" with the columns above.

# %%
# Create a new column that finds the average amount pledged to a project

# %%
# First convert "average_donation", "goal", and "pledged" columns to float
# Then Format to go to two decimal places, include a dollar sign, and use comma notation

# %%
# Calculate the total number of backers for all US projects

# %%
# Calculate the average number of backers for all US projects

# %%
# Collect only those US campaigns that have been picked as a "Staff Pick"

# %%
# Group by the state of the campaigns and see if staff picks matter (Seems to matter quite a bit)
